# %% [markdown]
# Para averiguar qué lecciones debes revisar antes de completar este próximo proyecto, responde las siguientes preguntas:
#
# En el proceso de desarrollo del modelo, los datos se dividen en varios conjuntos o muestras. ¿Cómo se llaman? Elige todas las respuestas correctas que correspondan:
#
#
#     Dataset para el entrenamiento
#
#     ¡Correcto!
#
#     Conjunto de datos de validación
#
#     ¡Correcto!
#
#     Dataset de prueba
#
#     ¡Correcto!

# %% [markdown]
# Necesitas calcular el valor EAM. Elige la definición correcta:
#
#     Valor de error absoluto medio

# %% [markdown]
# ¿Cuándo ocurre el desequilibrio de clases? Elige la respuesta correcta:
#
#     Las clases contienen diferentes números de observación

# %% [markdown]
# Elige los modelos ML:
#
# Regresion logistica, Bosque aleatoria

# %% [markdown]
# Otras tecnicas y metodos
#
# Bootstrap
#
# Bootstrap es una técnica para estimar estadísticas de población. Revisa el capítulo “Entrenar tu primer modelo” del curso "Introducción al machine learning" y las lecciones sobre bootstrap del curso "Aprendizaje automático en los negocios”.
#
# Clasificación ajustada por peso
#
# Es un método para resolver el problema del desequilibrio de clases. Revisa el capítulo "Primer modelo entrenado" del curso "Introducción al machine learning" y el capítulo "Clasificación desequilibrada" del curso "Aprendizaje supervisado".
#
# Profundidad máxima del árbol de decisión
#
# El árbol de decisión es un modelo y su profundidad máxima es un hiperparámetro. Revisa los capítulos "Primer modelo entrenado" y "Mejora del modelo", del curso "Introducción al machine learning".

# %% [markdown]
# Soft Skills
#
# Este diagrama de flujo te ayudará a determinar qué hacer en cada etapa del trabajo con las tareas.
#
# ![soft-skills.png](attachment:soft-skills.png)
